# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
train_dir = r"C:\Users\HP\Documents\Final Project\train"
val_dir   = r"C:\Users\HP\Documents\Final Project\val"

IMG_SIZE = 256        # Higher resolution helps accuracy
BATCH_SIZE = 16

# %%
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=8,
    zoom_range=0.15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

NUM_CLASSES = train_data.num_classes
CLASS_NAMES = list(train_data.class_indices.keys())

print("Classes:", CLASS_NAMES)
# Out:
# Found 697 images belonging to 9 classes.
# Found 181 images belonging to 9 classes.
# Classes: ['Actinic keratosis', 'Atopic Dermatitis', 'Benign keratosis', 'Dermatofibroma', 'Melanocytic nevus', 'Melanoma', 'Squamous cell carcinoma', 'Tinea Ringworm Candidiasis', 'Vascular lesion']

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_data.classes),
    y=train_data.classes
)

class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: 0.9680555555555556, 1: 0.9561042524005487, 2: 0.9680555555555556, 3: 0.9680555555555556, 4: 0.9680555555555556, 5: 0.9680555555555556, 6: 0.9680555555555556, 7: 1.382936507936508, 8: 0.9680555555555556}

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Phase 1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14596\4130236286.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.4)(x)
output = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 128, 128,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 128, 128,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
callbacks_phase1 = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, min_lr=1e-6),
    ModelCheckpoint("best_model_phase1.keras", monitor="val_accuracy", save_best_only=True)
]

# %%
history_phase1 = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10,
    callbacks=callbacks_phase1
)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 770ms/step - accuracy: 0.3768 - loss: 2.0406 - val_accuracy: 0.6409 - val_loss: 0.9998 - learning_rate: 0.0010
# Epoch 2/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 729ms/step - accuracy: 0.6769 - loss: 0.9679 - val_accuracy: 0.7017 - val_loss: 0.8566 - learning_rate: 0.0010
# Epoch 3/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 812ms/step - accuracy: 0.7162 - loss: 0.8250 - val_accuracy: 0.7182 - val_loss: 0.7972 - learning_rate: 0.0010
# Epoch 4/10
# ...

# %%
base_model.trainable = True

for layer in base_model.layers[:-15]:
    layer.trainable = False

# %%
model.compile(
    optimizer=Adam(learning_rate=5e-6),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
callbacks_phase2 = [
    EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=4,
        min_lr=1e-6
    ),
    ModelCheckpoint(
        "best_model_finetuned.keras",
        monitor="val_accuracy",
        save_best_only=True
    )
]

history_phase2 = model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 45s 834ms/step - accuracy: 0.5405 - loss: 1.4142 - val_accuracy: 0.7624 - val_loss: 0.6696 - learning_rate: 5.0000e-06
# Epoch 2/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 826ms/step - accuracy: 0.6159 - loss: 1.0858 - val_accuracy: 0.7680 - val_loss: 0.6706 - learning_rate: 5.0000e-06
# Epoch 3/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 815ms/step - accuracy: 0.6864 - loss: 0.9048 - val_accuracy: 0.7735 - val_loss: 0.6713 - learning_rate: 5.0000e-06
# Epoch 4/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 34s 762ms/step - accuracy: 0.6894 - loss: 0.8508 - val_accuracy: 0.7680 - val_loss: 0.6740 - learning_rate: 5.0000e-06
# Epoch 5/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 33s 757ms/step - accuracy: 0.7373 - loss: 0.7709 - val_accuracy: 0.7569 - val_loss: 0.6751 - learning_rate: 5.0000e-06
# Epoch 6/30
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 856ms/step - accuracy: 0.7544 - loss: 0.7214 - val_accuracy: 0.7624 - val_loss: 0.6733 - learning_rate: 1.5000e-06
# Epoch 7/30
# ...

# %%
loss, acc = model.evaluate(val_data)
print(f"Final Validation Accuracy: {acc * 100:.2f}%")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - accuracy: 0.7413 - loss: 0.7068
# Final Validation Accuracy: 76.24%

# %%
y_true = val_data.classes
y_pred = np.argmax(model.predict(val_data), axis=1)

print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))

plt.figure(figsize=(9,7))
sns.heatmap(
    confusion_matrix(y_true, y_pred),
    annot=True,
    fmt="d",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 450ms/step
#                             precision    recall  f1-score   support
#
#          Actinic keratosis       0.73      0.55      0.63        20
#          Atopic Dermatitis       0.95      1.00      0.98        21
#           Benign keratosis       0.86      0.95      0.90        20
#             Dermatofibroma       0.71      0.50      0.59        20
#          Melanocytic nevus       0.81      0.65      0.72        20
#                   Melanoma       0.56      0.50      0.53        20
#    Squamous cell carcinoma       0.47      0.85      0.61        20
# Tinea Ringworm Candidiasis       1.00      0.85      0.92        20
#            Vascular lesion       0.95      1.00      0.98        20
#
#                   accuracy                           0.76       181
#                  macro avg       0.78      0.76      0.76       181
#               weighted avg       0.79      0.76      0.76       181

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

for layer in model.layers[-50:]:   # unfreeze last 50 layers
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=["accuracy"]
)

callbacks_boost = [
    EarlyStopping(
        monitor="val_loss",
        patience=6,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=3,
        min_lr=1e-7
    ),
    ModelCheckpoint(
        "best_model_accuracy_boost.keras",
        monitor="val_accuracy",
        save_best_only=True
    )
]

# %%
history_boost = model.fit(
    train_data,
    validation_data=val_data,
    epochs=15,
    callbacks=callbacks_boost
)
# Out:
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 49s 872ms/step - accuracy: 0.4852 - loss: 2.0060 - val_accuracy: 0.7403 - val_loss: 1.3127 - learning_rate: 1.0000e-05
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 830ms/step - accuracy: 0.6255 - loss: 1.4339 - val_accuracy: 0.7403 - val_loss: 1.3261 - learning_rate: 1.0000e-05
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 915ms/step - accuracy: 0.6716 - loss: 1.3551 - val_accuracy: 0.7348 - val_loss: 1.3262 - learning_rate: 1.0000e-05
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 41s 924ms/step - accuracy: 0.7045 - loss: 1.1943 - val_accuracy: 0.7403 - val_loss: 1.3290 - learning_rate: 1.0000e-05
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 917ms/step - accuracy: 0.7554 - loss: 1.1462 - val_accuracy: 0.7403 - val_loss: 1.3192 - learning_rate: 2.0000e-06
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 881ms/step - accuracy: 0.7427 - loss: 1.1202 - val_accuracy: 0.7348 - val_loss: 1.3118 - learning_rate: 2.0000e-06
# Epoch 7/15
# ...

# %%
import numpy as np

def tta_predict(model, generator, tta_steps=5):
    preds = []
    for _ in range(tta_steps):
        generator.reset()
        preds.append(model.predict(generator))
    return np.mean(preds, axis=0)

# Run TTA
y_pred_tta = tta_predict(model, val_data, tta_steps=5)
y_pred = np.argmax(y_pred_tta, axis=1)
y_true = val_data.classes

from sklearn.metrics import accuracy_score
print("TTA Validation Accuracy:", accuracy_score(y_true, y_pred) * 100)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 528ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 425ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 454ms/step
# TTA Validation Accuracy: 74.58563535911603

# %%
import tensorflow as tf

# ---- Focal Loss Definition ----
def focal_loss(gamma=2.0, alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        return tf.reduce_mean(weight * cross_entropy)
    return loss_fn


# ---- Recompile Model (IMPORTANT) ----
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=focal_loss(gamma=2.0, alpha=0.25),
    metrics=["accuracy"]
)


# ---- Train Again (SHORT & SAFE) ----
history_focal = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.7340 - loss: 0.0123 - val_accuracy: 0.6685 - val_loss: 0.0186 - learning_rate: 1.0000e-04
# Epoch 2/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8308 - loss: 0.0068 - val_accuracy: 0.6575 - val_loss: 0.0193 - learning_rate: 1.0000e-04
# Epoch 3/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.8251 - loss: 0.0058 - val_accuracy: 0.6685 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 4/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9062 - loss: 0.0035 - val_accuracy: 0.6133 - val_loss: 0.0210 - learning_rate: 1.0000e-04
# Epoch 5/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9149 - loss: 0.0027 - val_accuracy: 0.6575 - val_loss: 0.0181 - learning_rate: 1.0000e-04
# Epoch 6/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9403 - loss: 0.0027 - val_accuracy: 0.6796 - val_loss: 0.0169 - learning_rate: 1.0000e-04
# Epoch 7/10
# ...

# %%
# 1️⃣ Freeze most of the backbone again
for layer in model.layers[:-30]:
    layer.trainable = False


# 2️⃣ Recompile with LOWER learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # LOWER LR
    loss=focal_loss(gamma=2.0, alpha=0.25),
    metrics=["accuracy"]
)


# 3️⃣ Train VERY SHORT (stability training)
history_stable = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.9071 - loss: 0.0027 - val_accuracy: 0.6906 - val_loss: 0.0161 - learning_rate: 1.0000e-05
# Epoch 2/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9300 - loss: 0.0024 - val_accuracy: 0.6961 - val_loss: 0.0160 - learning_rate: 1.0000e-05
# Epoch 3/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.9333 - loss: 0.0022 - val_accuracy: 0.7017 - val_loss: 0.0159 - learning_rate: 1.0000e-05
# Epoch 4/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9223 - loss: 0.0031 - val_accuracy: 0.7182 - val_loss: 0.0156 - learning_rate: 1.0000e-05
# Epoch 5/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9392 - loss: 0.0023 - val_accuracy: 0.7127 - val_loss: 0.0153 - learning_rate: 1.0000e-05
# Epoch 6/25
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.9353 - loss: 0.0028 - val_accuracy: 0.7182 - val_loss: 0.0152 - learning_rate: 1.0000e-05
# Epoch 7/25
# ...

# %%
loss, acc = model.evaluate(val_data)
print(f"Improved Validation Accuracy: {acc * 100:.2f}%")

loss, acc = model.evaluate(train_data)
print(f"Improved Training Accuracy: {acc * 100:.2f}%")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step - accuracy: 0.7656 - loss: 0.0177
# Improved Validation Accuracy: 80.11%
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 35s 790ms/step - accuracy: 0.9651 - loss: 8.2836e-04
# Improved Training Accuracy: 96.56%
